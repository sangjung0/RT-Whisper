# %%
import os
import sys
os.chdir("/workspaces/dev")
paths = [
    "/workspaces/dev/modules/python-utils",
    "/workspaces/dev/modules/ai-utils",
]
for path in paths:
    sys.path.append(os.path.abspath(path))
print(f"Current Python version: {sys.version}")

# %%
from pathlib import Path
import joblib

# %%
STUDY = "/workspaces/dev/study/esic/20250721_study_16_batch.pkl"

# %%
study_path = Path(STUDY)
if not study_path.exists():
    raise FileNotFoundError(f"Study path {study_path} does not exist.")
study = joblib.load(study_path)

# %%
len(study.trials)
