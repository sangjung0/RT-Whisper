# %%
import os
import sys
os.chdir("/workspaces/dev")
paths = [
    "/workspaces/dev/modules/python-utils",
    "/workspaces/dev/modules/ai-utils",
]
for path in paths:
    sys.path.append(os.path.abspath(path))
print(f"Current Python version: {sys.version}")

# %%
from pathlib import Path

# %%
from rt_whisper_optimizer import ESICOptimizer

# %%
SOURCE = "/workspaces/dev/datasets/ESIC-v1.1/v1.1/dev"
STORAGE = "/workspaces/dev/storage/esic/"
STUDY = "/workspaces/dev/study/esic/"
OUTPUT = "/workspaces/dev/hyperparameters/esic/20250729/001-3"
STUDY_INSTRUCTION = "/workspaces/dev/study_param/esic/20250729/001-3.yaml"

# %%
source = Path(SOURCE)
storage = Path(STORAGE)
study = Path(STUDY)
output = Path(OUTPUT)

# %%
esic_optimizer = ESICOptimizer(source, study, output, storage)

# %%
esic_optimizer.optimize(Path(STUDY_INSTRUCTION))
