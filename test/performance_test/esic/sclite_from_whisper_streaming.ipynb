# %%
import os
import sys
os.chdir("/workspaces/dev")
paths = [
    "/workspaces/dev/test/performance_test",
]
for path in paths:
    sys.path.append(os.path.abspath(path))
print(f"Current Python version: {sys.version}")

# %%
from pathlib import Path

# %%
from sj_ai_utils.datasets.esic_v1 import ESICv1Dataset

# %%
from common_util import whisper_streaming

# %%
RANDOM_SEED = 42
CHUNK_SIZE = 48000
TEST_ALL = True
SAMPLE_SIZE = 1

# %%
ESIC_VAL = "/workspaces/dev/test/performance_test/esic/data/val.json"

# %%
esic_val = Path(ESIC_VAL)

if not esic_val.exists():
    raise FileNotFoundError(f"ESIC validation file does not exist: {esic_val}")

# %%
dataset = ESICv1Dataset.load(esic_val).sample(SAMPLE_SIZE)

# %%
whisper_streaming(
    dataset,
    seed = RANDOM_SEED,
    chunk_size=CHUNK_SIZE,
    test_all=TEST_ALL,
)
