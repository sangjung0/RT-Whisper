# %% [markdown]
# ### RT Whisper 하이퍼파라미터 리스트 평가

# %%
import os
import sys
os.chdir("/workspaces/dev")
paths = [
    "/workspaces/dev/test/performance_test/libri",
]
for path in paths:
    sys.path.append(os.path.abspath(path))
print(f"Current Python version: {sys.version}")

# %%
from pathlib import Path

# %%
from sj_ai_utils.datasets.libri_speech_asr_corpus.service import search_dirs

# %%
from util import evaluate

# %%
SEED = 42
MAX_COUNT = 1
TEST_ALL = True
USE_TOKEN_SAVER_LOADER = True
USE_PROMPT = False
CHUNK_SIZE = 48000
# SOURCE = "/workspaces/dev/datasets/LibriSpeechASRcorpus/test-clean" # use in test
SOURCE = "/workspaces/dev/.datasets/LibriSpeechASRcorpus/dev-clean" # use in val
STORAGE = "/workspaces/dev/.storage/libri/"
HYPERPARAMETER = "/workspaces/dev/test/optimize/esic/hyperparameters/20250731/step1_16b-96k/trial_wer3o0_6690_20250801_074742.yaml"
OUTPUT_PATH = "/workspaces/dev/test/performance_test/libri/output/test.json"

# %%
DESCRIPTION = """
test
"""

# %%
TEST_MODELS = ["rt_whisper"]
# TEST_MODELS = ["whisper", "rt_whisper", "whisper_streaming"]

# %%
source = Path(SOURCE)
storage = Path(STORAGE)
hyperparameter_path = Path(HYPERPARAMETER)
output_path = Path(OUTPUT_PATH)

if not source.exists():
    raise FileNotFoundError(f"Source path does not exist: {source}")
if not hyperparameter_path.exists():
    raise FileNotFoundError(f"Hyperparameter path does not exist: {hyperparameter_path}")
if output_path.exists():
    raise FileExistsError(f"Output path already exists: {output_path}")

# %%
data_paths = search_dirs(source)

# %%
evaluate(
    storage,
    output_path,
    DESCRIPTION,
    data_paths,
    models = TEST_MODELS,
    test_all = TEST_ALL,
    max_count=MAX_COUNT,
    seed = SEED,
    use_save_loader=USE_TOKEN_SAVER_LOADER,
    use_prompt=USE_PROMPT,
    hyperparameter = hyperparameter_path,
    chunk_size=CHUNK_SIZE
)
