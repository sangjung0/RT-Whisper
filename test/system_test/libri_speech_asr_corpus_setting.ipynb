# %%
import os
import sys
os.chdir("/workspaces/dev")
sys.path.append(
    "./modules/python-utils:./modules/ai-utils"
)

# %%
from pathlib import Path

# %%
from sj_ai_utils.datasets.libri_speech_asr_corpus import trans_txt_to_sclite_trn

# %%
SOURCE = "/workspaces/dev/datasets/LibriSpeechASRcorpus"
DESTINATION = "/workspaces/dev/datasets/LibriSpeechASRcorpus/sclient"

# %%
src = Path(SOURCE)
dst = Path(DESTINATION)

# %%
dst.mkdir(parents=True, exist_ok=True)

# %%
# test-other/LibriSpeech/test-other

test_other = src / "test-other" / "LibriSpeech" / "test-other"

# %%
trans_txt_files = test_other.rglob("*.trans.txt")

# %%
trans_txt_files[0:10]

# %%
trans_txt_to_sclite_trn(trans_txt_files[0], dst / "test-other")
