# %%
import os
import sys
os.chdir("/workspaces/dev")
sys.path.append("/workspaces/dev/modules/python-utils")
# sys.path.append("/workspaces/dev/modules")

# %%
import librosa

# %%
from rt_whisper.transcribers import get_transcriber

# %%
SAMPLE_RATE = 16000

# %%
audio, sr = librosa.load("/workspaces/dev/.data/news_with_English.mp3", sr=SAMPLE_RATE)

# %%
transcriber = get_transcriber()

# %%
raise Exception("stop")

# %%
from rt_whisper import Param
from IPython.display import Audio

# %%
param = Param()
param.chunk = audio
result = transcriber.process(param)

# %%
for v in result.completed:
    print(v.text)
Audio(param.chunk, rate=SAMPLE_RATE)
